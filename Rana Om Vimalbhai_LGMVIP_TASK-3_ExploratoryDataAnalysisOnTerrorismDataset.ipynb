# %% [markdown]
# # RANA OM VIMALBHAI
#
# ## Data Science Intern at LetsGrowMore
#
# ## Task-3 : Exploratory Data Analysis on Dataset-Terrorism

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the dataset

# %%
df=pd.read_csv('terrorism.csv',encoding='ISO-8859-1', low_memory=False)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
# number of rows and columns in new_dataset

print("Number of rows:",df.shape[0])
print("Number of columns:",df.shape[1])
# Out:
# Number of rows: 181691
# Number of columns: 135

# %% [markdown]
# ## Modifying the original data

# %%
# renaming the columns

df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
df.head()
# Out:
#         eventid  Year  Month  Day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#               Country  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
new_data=df[['Year','Month','Day','Country','state','Region','city','latitude','longitude','AttackType','Killed',
               'Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]

# %%
new_data.head()
# Out:
#    Year  Month  Day             Country    state                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             city   latitude   longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
# extracted new_data contains only 18 columns after optimising

new_data.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'state', 'Region', 'city',
#        'latitude', 'longitude', 'AttackType', 'Killed', 'Wounded', 'Target',
#        'Summary', 'Group', 'Target_type', 'Weapon_type', 'Motive'],
#       dtype='object')

# %% [markdown]
# ## Checking for null values in dataset

# %%
new_data.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# state             421
# Region              0
# city              434
# latitude         4556
# longitude        4557
# AttackType          0
# Killed          10313
# Wounded         16311
# Target            636
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# dtype: int64

# %% [markdown]
# ## Data Exploration

# %%
# plotting heat map

plt.figure(figsize=(9,6))
new_data.corr()
sns.heatmap(new_data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# plotting the histogram

new_data.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# ## Terrorist activities in each region through area plot

# %%
# a crosstab is a table showing the relationship between two or more variables.
# plotting area plot graph

pd.crosstab(new_data.Year, new_data.Region).plot(kind='area',figsize=(12,5))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.grid()
plt.show()

# %% [markdown]
# ## Counting terrorist activities each year through countplot

# %%
# plotting count graph

plt.subplots(figsize=(15,5))
sns.countplot(x='Year',data = new_data)
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Activities Each Year')
plt.grid()
plt.show()

# %% [markdown]
# ## Calculating the percentage of attacks that has happened between 1970 and 2017

# %%
Year=new_data.Year.value_counts().to_dict()
rate=((Year[2017]-Year[1970])/Year[2017])*100
print(Year[1970],'attacks happened in 1970 !')
print(Year[2017],'attacks happened in 2017 !')
print('Total number of attacks from 1970 has increased by',np.round(rate,0),'% till 2017 !')
# Out:
# 651 attacks happened in 1970 !
# 10900 attacks happened in 2017 !
# Total number of attacks from 1970 has increased by 94.0 % till 2017 !

# %% [markdown]
# ## Different types of attacks

# %%
plt.figure(figsize=(16,3))
sns.countplot(x = new_data['AttackType'], order = new_data['AttackType'].value_counts().index)
plt.xticks(rotation=70)
plt.xlabel('Method')
plt.title('Method of Attack')
plt.show()

# %% [markdown]
# ## Different types of targets

# %%
plt.figure(figsize=(16,5))
sns.countplot(x = new_data['Target_type'], order=new_data['Target_type'].value_counts().index)
plt.xticks(rotation=70)
plt.xlabel('Type')
plt.title('Type of Target')
plt.grid()
plt.show()

# %% [markdown]
# ## Destructive Feature of data

# %%
#Destructive Feature of data

print("Country with the most attacks:",new_data['Country'].value_counts().idxmax())
print("City with the most attacks:",new_data['city'].value_counts().index[1]) #as first entry is 'unknown'
print("Region with the most attacks:",new_data['Region'].value_counts().idxmax())
print("Year with the most attacks:",new_data['Year'].value_counts().idxmax())
print("Month with the most attacks:",new_data['Month'].value_counts().idxmax())
print("Group with the most attacks:",new_data['Group'].value_counts().index[1])
print("Most Attack Types:",new_data['AttackType'].value_counts().idxmax())
# Out:
# Country with the most attacks: Iraq
# City with the most attacks: Baghdad
# Region with the most attacks: Middle East & North Africa
# Year with the most attacks: 2014
# Month with the most attacks: 5
# Group with the most attacks: Taliban
# Most Attack Types: Bombing/Explosion

# %% [markdown]
# ## Top Countries affected by Terror Attacks

# %%
#Top Countries affected by Terror Attacks

plt.subplots(figsize=(15,6))
sns.barplot(new_data['Country'].value_counts()[:15].index,new_data['Country'].value_counts()[:15].values,palette='Blues_d')
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()
# Out:
# C:\Users\DC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
# Total Number of people killed in terror attack
killData = new_data.loc[:,'Killed']
print('Number of people killed by terror attack:', int(sum(killData.dropna())))# drop the NaN values
# Out:
# Number of people killed by terror attack: 12795

# %%
# Let's look at what types of attacks these deaths were made of.
attackData = new_data.loc[:,'AttackType']
# attackData
typeKillData = pd.concat([attackData, killData], axis=1)
typeKillData.head()
# Out:
#                          AttackType  Killed
# 73126                     Hijacking    1384
# 73127                     Hijacking    1383
# 58841               Unarmed Assault      13
# 68071             Bombing/Explosion     224
# 133518  Hostage Taking (Kidnapping)    1570

# %% [markdown]
# ## Count of terrorist attacks in each countries and regions

# %%
fig,axes = plt.subplots(figsize=(16,5),nrows=1,ncols=2)
sns.barplot(x = new_data['Country'].value_counts()[:20].values, y = new_data['Country'].value_counts()[:20].index, ax=axes[0]);
axes[0].set_title('Terrorist Attacks per Country')
sns.barplot(x=new_data['Region'].value_counts().values, y=new_data['Region'].value_counts().index, ax=axes[1])
axes[1].set_title('Terrorist Attacks per Region')
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Count of attacks in each country using globe

# %%
df=new_data.groupby(['Country'],as_index=False).count()

# %%
df.head()
# Out:
#        Country   Year  Month    Day  state  Region   city  latitude  \
# 0  Afghanistan  12731  12731  12731  12731   12731  12592     12639
# 1      Albania     80     80     80     71      80     80        79
# 2      Algeria   2743   2743   2743   2706    2743   2736      2617
# 3      Andorra      1      1      1      1       1      1         0
# 4       Angola    499    499    499    499     499    499       465
#
#    longitude  AttackType  Killed  Wounded  Target  Summary  Group  \
# 0      12639       12731   12362    11994   12715    12617  12731
# 1         79          80      76       76      78       25     80
# 2       2617        2743    2719     2630    2708     1612   2743
# 3          0           1       0        0       1        0      1
# 4        465         499     482      462     495      133    499
#
#    Target_type  Weapon_type  Motive
# 0        12731        12731    3586
# 1           80           80      17
# 2         2743         2743    1507
# ...

# %% [markdown]
# ## Finding out the terrorist organizations that carried out the operations in different countries

# %%
plt.subplots(figsize=(11,5))
sns.barplot(y=new_data['Group'].value_counts()[1:12].index,x=new_data['Group'].value_counts()[1:12].values)
plt.title('Most Active Terrorist Organizations')
plt.show()

# %%
print('Country with Highest Terrorist Attacks:',df['Country'].value_counts().index[0])
print('Regions with Highest Terrorist Attacks:',df['Region'].value_counts().index[0])
print('Maximum people killed in an attack are:',df['Killed'].max(),'that took place in',df.loc[df['Killed'].idxmax()].Country)
# Out:
# Country with Highest Terrorist Attacks: Afghanistan
# Regions with Highest Terrorist Attacks: 1
# Maximum people killed in an attack are: 23911 that took place in Iraq
